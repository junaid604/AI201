# %% [markdown]
# <a href="https://colab.research.google.com/github/junaid604/AI201/blob/main/image_assign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
userdata.get('GOOGLE_API_KEY')
# Out:
# 'AIzaSyCk5F9s1NtD5SNMlRcw-_KI_uNkCMoE-og'

# %%
import google.generativeai as genai

# %%
genai.configure(api_key='AIzaSyCk5F9s1NtD5SNMlRcw-_KI_uNkCMoE-og')

# %%
model = genai.GenerativeModel('gemini-1.5-flash')

# %%
import PIL.Image as img
image = img.open("pic.jpg")
display(image)
prompt = "explain this image in details"
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x944>

# %%
response = model.generate_content([image,prompt])
print(response.text)
# Out:
# Here's a description of the image:
#
# Close-up view of a brightly colored butterfly perched on a cluster of orange flowers.
#
#
# Here's a breakdown of the details:
#
# * **The Butterfly:** The butterfly is the central focus, occupying a significant portion of the frame. Its wings are a striking pattern of black, orange, red, white, and hints of blue, creating a very intricate and vibrant design. The wing edges are scalloped. The butterfly's body is slender and dark.
#
# * **The Flowers:** The flowers are a rich, warm orange, appearing slightly wet or dewy. They are clustered together, forming a dense group. The individual blossoms are small and tubular.
#
# * **The Background:** The background is softly blurred (bokeh effect), showcasing a shallow depth of field that emphasizes the butterfly and flowers. The colors are muted greens and oranges, providing a complementary backdrop without distracting from the main subjects.
#
# ...
